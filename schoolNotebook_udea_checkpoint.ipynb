# %% [markdown]
# # Taller de redes neuronales aplicadas a espectros estelares
#
# En este notebook se va a entrenar una red neuronal utilizando la librería sklearn. En concreto, la red neuronal es un objeto de la clase [sklearn.neural_network.MLPRegresor](https://scikit-learn.org/stable/modules/generated/sklearn.neural_network.MLPRegressor.html). Posteriormente se utilizará la red neuronal entrenada para inferir parámetros astrofísicos de un conjunto de estrellas cuyos espectros fueron medidos con [RAVE](https://www.rave-survey.org/).
#
# Para entrenar dicha red se han generado espectros sintéticos que se han guardado en el fichero *grid_school_v2_8420_8785_003899999999998727.pkl*. Dentro del fichero está guardado, además de los espectros, la temperatura efectiva, el logaritmo de la gravedad y la metalicidad que corresponde a cada espectro; todo ello en formato tabla como un objeto [pandas.DataFrame](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html).

# %% [markdown]
# Para comenzar importamos las librerías necesarias:

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pickle

from warnings import simplefilter
simplefilter(action="ignore",category=FutureWarning)

# %matplotlib inline

# %% [markdown]
# Además de las librerías que se han mencionado, se han importado las funciones [train_test_split](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html) y [MinMaxScaler](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html) que serán de utilidad para trabajar con los datos de entrenamiento

# %%
# Código auxiliar: aunque no es necesario, se definen las longitudes de onda tanto de las simulaciones como de las observaciones
wlen = np.arange(842,878.5,0.03899999999998727)

# %% [markdown]
# ## 1 Preparación de los datos

# %% [markdown]
# ### 1.1 Lectura de las simulaciones
#
# Primero hay que cargar las simulaciones. Para ello hay que utilizar la función *pandas.read_pickle* que acepta como argumento el nombre del fichero a leer y devuelve un *DataFrame* (nota: para llamar a las funciones de pandas hay que usar pd en lugar de pandas, ya que en la cabecera se ha llamado a la instrucción
# ```
# import pandas as pd
# ```

# %%
grid = pd.read_pickle("data/grid_school_v2_8420_8785_003899999999998727.pkl") # rellenar

# %% [markdown]
# Una vez leído, la variable *grid* tiene estructura de tabla, para saber qué columnas hay almacenadas dentro se puede llamar al atributo *columns*.

# %%
cols = grid.columns  # rellenar
print(cols) #rellenar
# Out:
# Index(['teff', 'logg', 'm_h', 'spectrum'], dtype='object')

# %% [markdown]
# Si se quieren ver las primeras filas de la tabla se puede llamar al método *head()* que tiene todo *DataFrame*. El resultado debería ser igual a
#
# |  |   teff | logg |  m_h |                                          spectrum|
# |--|--------|------|------|--------------------------------------------------|
# |0 | 3000.0 |  0.0 |-3.00 | [0.9997522849383049, 0.9998009367060697, 0.999...|
# |1 | 3000.0 |  0.0 |-2.75 | [0.9997123698112049, 0.9997728740768044, 0.999...|
# |2 | 3000.0 |  0.0 |-2.50 | [0.999568427270208, 0.9996652039896338, 0.9997...|
# |3 | 3000.0 |  0.0 |-2.25 | [0.9993215807872953, 0.9994811204761738, 0.999...|
# |4 | 3000.0 |  0.0 |-2.00 | [0.9991882596346863, 0.9993762569755674, 0.999...|
#
# Por otro lado, si queremos ver una columna en concreto (por ejemplo, la columna j), se puede acceder a ella mediante
# ```
# nombreDataFrame.iloc[j]
# ```

# %%
# Rellenar la celda para mostrar las primeras filas almacenadas en grid
grid.head()
# Out:
#      teff  logg   m_h                                           spectrum
# 0  3000.0   0.0 -3.00  [0.9997522849383049, 0.9998009367060697, 0.999...
# 1  3000.0   0.0 -2.75  [0.9997123698112049, 0.9997728740768044, 0.999...
# 2  3000.0   0.0 -2.50  [0.999568427270208, 0.9996652039896338, 0.9997...
# 3  3000.0   0.0 -2.25  [0.9993215807872953, 0.9994811204761738, 0.999...
# 4  3000.0   0.0 -2.00  [0.9991882596346863, 0.9993762569755674, 0.999...

# %% [markdown]
# ### 1.2 Visualización de las simulaciones

# %% [markdown]
# En la celda siguiente hay un ejemplo en el que se pinta el espectro almacenado en la primera fila del *DataFrame*.

# %%
idx = 100
spec = grid["spectrum"].iloc[idx]
teff = grid["teff"].iloc[idx]
logg = grid["logg"].iloc[idx]
mh = grid["m_h"].iloc[idx]
label_spec = "Teff = {} log(g) = {} [m/H] = {}".format(teff,logg,mh) 

plt.figure(figsize=(16,8))
plt.plot(wlen,spec,label=label_spec)
plt.xlabel(r"$\lambda /nm$",size=20)
plt.ylabel(r"Normalized flux",size=20)
plt.xticks(size=20)
plt.legend()

# %% [markdown]
# En la misma figura se pueden representar varios espectros.

# %%
idx1 = 122 # elige una fila para el primer espectro
idx2 = 5 # elige otra fila para el segundo espectro

spec1 = grid["spectrum"].iloc[idx1] # rellenar
teff1 = grid["teff"].iloc[idx1] # rellenar
logg1 = grid["logg"].iloc[idx1] # rellenar
mh1 = grid["m_h"].iloc[idx1] # rellenar
label_spec1 = "Teff = {} log(g) = {} [m/H] = {}".format(teff1,logg1,mh1)  # rellenar

# rellenar para definir las variables del segundo espectro
spec2 = grid["spectrum"].iloc[idx2] # rellenar
teff2 = grid["teff"].iloc[idx2] # rellenar
logg2 = grid["logg"].iloc[idx2] # rellenar
mh2 = grid["m_h"].iloc[idx2] # rellenar
label_spec2 = "Teff = {} log(g) = {} [m/H] = {}".format(teff2,logg2,mh2)  # rellenar


# rellenar para dibujar los dos espectros
plt.figure(figsize=(16,8))
plt.plot(wlen,spec1,label=label_spec1)
plt.plot(wlen,spec2,label=label_spec2)
plt.xlabel(r"$\lambda /nm$",size=20)
plt.ylabel(r"Normalized flux",size=20)
plt.xticks(size=20)
plt.legend()

# %% [markdown]
# Además, se pueden seleccionar las columnas guardadas en el *DataFrame* de *pandas* simplemente poniendo entre corchetes los nombres de las variables

# %%
teffs = grid["teff"] # rellenar para escoger la columna de las temperaturas
loggs = grid["logg"] # columna de las gravedades
mhs = grid["m_h"] # columna de las metalicidades

plt.figure(figsize=(21,8))
plt.subplot(131)
plt.hist(teffs,bins=100)
plt.xlabel(r"$T_{eff}$")
plt.subplot(132)
plt.hist(loggs,bins=100)
plt.xlabel(r"$log(g)$")
plt.subplot(133)
plt.hist(mhs,bins=100)
plt.xlabel(r"$[M/H]$")
# Out:
# Text(0.5, 0, '$[M/H]$')

# %% [markdown]
# ### 1.3 Preparación de las simulaciones

# %% [markdown]
# Una vez observados y entendidos los datos simulados con los que se puede trabajar es cuando se van a preparar para poder usarlos en el entrenamiento de la red neuronal.
#
# La red es lo que se llama un perceptrón totalmente conectado y queremos entrenarlo para que lea un espectro y como resultado nos diga qué parámetros astrofísicos (temperatura efectiva, logaritmo de la gravedad y metalicidad) tiene la estrella que produce dicho espectro. Por tanto, los valores de entrada de la red serán los valores del espectro para las distintas longitudes de onda y los valores de salida serán tres: temperatura, gravedad y metalicidad.

# %%
y = grid[["teff","logg","m_h"]].values
x = grid["spectrum"].values # rellenar 
x = np.array([xx.astype(float) for xx in x]) # este paso es necesario debido a la implementación de sklearn

# %% [markdown]
# A la hora de ayudar al programa de minimización a encontrar el mínimo es útil escalar las variables de manera que el rango entre ellas sea aproximadamente igual. Para esto vamos a utilizar el objeto [MinMaxScaler](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html) de la librería *sklearn*

# %%
scaler = MinMaxScaler()
ys = scaler.fit_transform(y) # rellenar con la variable que se quiere escalar

# %% [markdown]
# Una vez preprocesados los datos sintéticos hay que decidir qué datos se utilizarán para entrenar y cuáles de ellos (el resto) para comprobar. Ésto se logra fácilmente con la función *train_test_split* que recibe como primer y segundo argumentos dos *arrays* que va a separar en dos conjuntos cada uno de ellos, el conjunto de entrenamiento (*train*) y el conjunto de comprobación (*test*). Además, admite otro argumento mediante la [clave](https://docs.python.org/3/glossary.html#term-argument) *test_size* cuyo valor va de 0 a 1 y que define qué porcentaje de elementos de los arrays se utilizarán para entrenar y qué porcentaje se utilizarán para comprobar. Los valores típicos suelen ser 0.1, 0.15 y 0.2.

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,ys,test_size=0.2) # rellenar

# %%
# rellenar la celda para mostrar tres gráficas con las variables de referencia que se usarán para entrenar
# nota: en una celda anterior se mostraron gráficas con los parámetros astrofísicos de entrada, ésta puede ser de ayuda
teffs = ytrain[:,0] # rellenar para escoger la columna de las temperaturas
loggs = ytrain[:,1] # columna de las gravedades
mhs = ytrain[:,2] # columna de las metalicidades

plt.figure(figsize=(21,8))
plt.subplot(131)
plt.hist(teffs,bins=100)
plt.xlabel(r"$T_{eff}$")
plt.subplot(132)
plt.hist(loggs,bins=100)
plt.xlabel(r"$log(g)$")
plt.subplot(133)
plt.hist(mhs,bins=100)
plt.xlabel(r"$[M/H]$")
# Out:
# Text(0.5, 0, '$[M/H]$')

# %% [markdown]
# A la vista de los gráficos anteriores, ¿se distribuyen los datos de entrenamiento como queremos?

# %% [markdown]
# ## 2 Construcción de la red

# %% [markdown]
# La definición de la red se hace a través de parámetros e hiperparámetros. Algunos de ellos hacen referencia a la arquitectura de la propia red mientras que otros definen la estrategia a seguir para la optimización de los parámetros de la red.

# %% [markdown]
# ### 2.1 Parámetros de la red
#
# Los parámetros que definen la red son las funciones de activación así como el número de capas
# ocultas y de neuronas por capa.
#
# Cuando se trabaja con *MLPRegressor* esto se hace con los argumentos *activation* y *hidden_layer_sizes*.
#
# - activation: función de activación de las neuronas. Admite un sólo valor entre "logistic", "linear", "tanh" y "relu"
# - hidden_layer_sizes: define el número de capas ocultas y el número de neuronas que hay en cada capa. El argumento es una tupla cuya longitud denota el número de capas ocultas y cuyos valores marcan el número de neuronas en las capas. Así, por ejemplo, una neurona con 2 capas ocultas y tres neuronas en cada capa vendría definida por
# ```
# hidden_layer_sizes=(3,3)
# ```

# %%
activation = "logistic" # elegir una función de activación
hidden_layer_sizes = (int(len(wlen)/4)) # elegir el número de capas ocultas así como las neuronas en cada capa
alpha = 1e-3 # término de regularización

# %% [markdown]
# ### 2.2 Parámetros para el optimizador
#
# Una vez definida la red quedan por definir tanto el optimizador como los parámetros que se
# pasarán a éste.
#
# El primero de ellos es el optimizador que se va a utilizar ("lbfgs", "sgd" o "adam"), mientras que los otros dos hacen referencia al desplazamiento de la solución que se obtiene tras cada iteración. Estos argumentos vienen especificados por *learning_rate_init* y por *learning_rate* que hacen referencia al valor del módulo del desplazamiento y los cambios que se le pueden aplicar respectivamente. Así, un valor de *learning_rate* igual a *"constant"* mantendrá el módulo del paso constante, mientras que *"adaptive"* lo irá variando en función de la solución actual en cada iteración.

# %%
solver = "adam" # elige un optimizador
learning_rate_init = 1e-3 # elige un paso
learning_rate = "adaptive" # elegir la estrategia a seguir con el paso

# %% [markdown]
# El siguiente conjunto de parámetros hace referencia a las iteraciones del optimizador en el proceso de minimización. Éstos son:
# - número máximo de iteraciones del optimizador: el optimizador realizará iteraciones hasta que converja o se alcance *max_iter*.
# - *tol*: define lo que se entiende por convergencia
# - *n_iter_no_change*: número máximo de iteraciones para que la función de pérdida disminuya

# %%
max_iter = 400 # número máximo de iteraciones
tol = 1e-4 # tolerancia
n_iter_no_change = 10 # númer máximo de épocas permitidas para que la función de pérdida disminuya

# %% [markdown]
# Finalmente, queda por definir el conjunto de validación. Este conjunto se puede definir a mano y no especificar el siguiente conjunto de parámetros, sin embargo, el objeto *MLPRegressor* nos permite hacer el proceso de creación del conjunto de validación simplemente especificando un parámetro

# %%
validation_fraction = 0.2 # fracción de elementos de entrada que se usarán para formar el conjunto de validación
early_stopping=True

# %% [markdown]
# ### 2.3 Definición de la red

# %%
net = MLPRegressor(
    activation=activation,
    hidden_layer_sizes=hidden_layer_sizes,
    solver=solver,
    learning_rate_init=learning_rate_init,
    learning_rate=learning_rate,
    max_iter=max_iter,
    tol=tol,
    n_iter_no_change=n_iter_no_change,
    validation_fraction=validation_fraction,
    verbose=True,
    early_stopping=early_stopping)

# %%
print(net)
# Out:
# MLPRegressor(activation='logistic', early_stopping=True, hidden_layer_sizes=234,
#              learning_rate='adaptive', max_iter=400, validation_fraction=0.2,
#              verbose=True)

# %% [markdown]
# ## 3 Entrenamiento
#
# Una vez definidos los conjuntos de entrenamiento y los parámetros de la red, el entrenamiento se hace a través del método *fit()* que recibe como primer argumento el conjunto de datos de entrada para el entrenamiento y como segundo el conjunto de datos de salida con los que debe contrastar la propia salida de la red. El proceso de ajuste de la red neuronal consiste, precisamente, en comparar las salidas de la red con el conjunto de entrada y minimizar el error cuadrático medio

# %%
# rellenar esta celda con la llamada a la función fit para entrenar la red
net.fit(xtrain,ytrain)
# Out:
# Iteration 1, loss = 0.08393738
# Validation score: 0.090075
# Iteration 2, loss = 0.03863946
# Validation score: 0.268540
# Iteration 3, loss = 0.03154487
# Validation score: 0.364011
# Iteration 4, loss = 0.02751883
# Validation score: 0.433162
# Iteration 5, loss = 0.02483990
# Validation score: 0.501543
# Iteration 6, loss = 0.02279891
# Validation score: 0.518553
# Iteration 7, loss = 0.02082966
# Validation score: 0.549642
# Iteration 8, loss = 0.01988197
# Validation score: 0.601511
# Iteration 9, loss = 0.01876943
# Validation score: 0.614059
# Iteration 10, loss = 0.01866942
# Validation score: 0.611940
# Iteration 11, loss = 0.01815621
# Validation score: 0.608952
# Iteration 12, loss = 0.01676541
# Validation score: 0.628427
# Iteration 13, loss = 0.01703467
# Validation score: 0.643304
# Iteration 14, loss = 0.01561398
# Validation score: 0.680724
# Iteration 15, loss = 0.01606967
# Validation score: 0.665203
# Iteration 16, loss = 0.01510851
# Validation score: 0.675936
# Iteration 17, loss = 0.01393745
# Validation score: 0.709777
# Iteration 18, loss = 0.01382730
# Validation score: 0.703791
# Iteration 19, loss = 0.01311604
# Validation score: 0.735450
# Iteration 20, loss = 0.01373390
# Validation score: 0.738003
# Iteration 21, loss = 0.01241175
# Validation score: 0.644166
# Iteration 22, loss = 0.01328876
# Validation score: 0.707007
# Iteration 23, loss = 0.01259207
# Validation score: 0.763025
# Iteration 24, loss = 0.01153745
# Validation score: 0.763659
# Iteration 25, loss = 0.01234809
# Validation score: 0.677287
# Iteration 26, loss = 0.01231455
# Validation score: 0.718612
# Iteration 27, loss = 0.01121479
# Validation score: 0.780011
# Iteration 28, loss = 0.01055007
# Validation score: 0.786309
# Iteration 29, loss = 0.01062306
# Validation score: 0.747050
# Iteration 30, loss = 0.01377856
# Validation score: 0.700750
# Iteration 31, loss = 0.01297935
# Validation score: 0.780043
# Iteration 32, loss = 0.01060984
# Validation score: 0.780354
# Iteration 33, loss = 0.01119885
# Validation score: 0.771933
# Iteration 34, loss = 0.01078661
# Validation score: 0.804405
# Iteration 35, loss = 0.00998539
# Validation score: 0.761371
# Iteration 36, loss = 0.00985630
# Validation score: 0.751692
# Iteration 37, loss = 0.01072392
# Validation score: 0.758932
# Iteration 38, loss = 0.01080403
# Validation score: 0.752721
# Iteration 39, loss = 0.01079855
# Validation score: 0.803477
# Iteration 40, loss = 0.00959501
# Validation score: 0.770006
# Iteration 41, loss = 0.01292463
# Validation score: 0.797871
# Iteration 42, loss = 0.01074769
# Validation score: 0.740482
# Iteration 43, loss = 0.01007761
# Validation score: 0.807353
# Iteration 44, loss = 0.00975360
# Validation score: 0.798931
# Iteration 45, loss = 0.00965218
# Validation score: 0.805149
# Iteration 46, loss = 0.01055962
# Validation score: 0.794674
# Iteration 47, loss = 0.00967427
# Validation score: 0.780441
# Iteration 48, loss = 0.00953725
# Validation score: 0.826577
# Iteration 49, loss = 0.00887681
# Validation score: 0.813124
# Iteration 50, loss = 0.00867109
# Validation score: 0.826213
# Iteration 51, loss = 0.00904308
# Validation score: 0.827727
# Iteration 52, loss = 0.00952984
# Validation score: 0.644154
# Iteration 53, loss = 0.01232569
# Validation score: 0.795803
# Iteration 54, loss = 0.00897048
# Validation score: 0.824040
# Iteration 55, loss = 0.00830874
# Validation score: 0.804231
# Iteration 56, loss = 0.00898607
# Validation score: 0.828341
# Iteration 57, loss = 0.01039362
# Validation score: 0.780180
# Iteration 58, loss = 0.00886090
# Validation score: 0.803164
# Iteration 59, loss = 0.01090635
# Validation score: 0.823961
# Iteration 60, loss = 0.00888423
# Validation score: 0.831387
# Iteration 61, loss = 0.00906845
# Validation score: 0.829743
# Iteration 62, loss = 0.00851153
# Validation score: 0.806891
# Iteration 63, loss = 0.00852370
# Validation score: 0.840773
# Iteration 64, loss = 0.00896329
# Validation score: 0.782448
# Iteration 65, loss = 0.00839152
# Validation score: 0.837312
# Iteration 66, loss = 0.00964263
# Validation score: 0.807181
# Iteration 67, loss = 0.00864132
# Validation score: 0.824402
# Iteration 68, loss = 0.00944031
# Validation score: 0.819484
# Iteration 69, loss = 0.00812861
# Validation score: 0.837590
# Iteration 70, loss = 0.00844116
# Validation score: 0.811519
# Iteration 71, loss = 0.00853599
# Validation score: 0.842645
# Iteration 72, loss = 0.00868012
# Validation score: 0.800440
# Iteration 73, loss = 0.00886365
# Validation score: 0.741677
# Iteration 74, loss = 0.00885231
# Validation score: 0.786346
# Iteration 75, loss = 0.00846772
# Validation score: 0.846775
# Iteration 76, loss = 0.00798318
# Validation score: 0.830257
# Iteration 77, loss = 0.00802607
# Validation score: 0.822009
# Iteration 78, loss = 0.00792818
# Validation score: 0.846048
# Iteration 79, loss = 0.00767809
# Validation score: 0.810617
# Iteration 80, loss = 0.00885052
# Validation score: 0.831149
# Iteration 81, loss = 0.00947898
# Validation score: 0.751374
# Iteration 82, loss = 0.00822789
# Validation score: 0.853445
# Iteration 83, loss = 0.00743782
# Validation score: 0.832241
# Iteration 84, loss = 0.00767402
# Validation score: 0.836823
# Iteration 85, loss = 0.00782314
# Validation score: 0.844193
# Iteration 86, loss = 0.00782727
# Validation score: 0.846233
# Iteration 87, loss = 0.00765976
# Validation score: 0.857573
# Iteration 88, loss = 0.00893742
# Validation score: 0.825764
# Iteration 89, loss = 0.00789909
# Validation score: 0.830717
# Iteration 90, loss = 0.00777640
# Validation score: 0.812646
# Iteration 91, loss = 0.00784904
# Validation score: 0.857520
# Iteration 92, loss = 0.00723916
# Validation score: 0.828197
# Iteration 93, loss = 0.00833379
# Validation score: 0.861217
# Iteration 94, loss = 0.00823943
# Validation score: 0.842172
# Iteration 95, loss = 0.00860619
# Validation score: 0.855907
# Iteration 96, loss = 0.00787301
# Validation score: 0.857317
# Iteration 97, loss = 0.00796018
# Validation score: 0.863053
# Iteration 98, loss = 0.00771032
# Validation score: 0.855522
# Iteration 99, loss = 0.00758179
# Validation score: 0.856385
# Iteration 100, loss = 0.00738321
# Validation score: 0.757787
# Iteration 101, loss = 0.00841347
# Validation score: 0.852836
# Iteration 102, loss = 0.00764938
# Validation score: 0.807117
# Iteration 103, loss = 0.00789049
# Validation score: 0.864201
# Iteration 104, loss = 0.00752786
# Validation score: 0.839166
# Iteration 105, loss = 0.00745381
# Validation score: 0.867938
# Iteration 106, loss = 0.00705008
# Validation score: 0.855415
# Iteration 107, loss = 0.00672763
# Validation score: 0.869043
# Iteration 108, loss = 0.00708211
# Validation score: 0.840493
# Iteration 109, loss = 0.00741996
# Validation score: 0.830530
# Iteration 110, loss = 0.00667899
# Validation score: 0.863875
# Iteration 111, loss = 0.00927048
# Validation score: 0.755058
# Iteration 112, loss = 0.00737676
# Validation score: 0.836709
# Iteration 113, loss = 0.00759856
# Validation score: 0.864909
# Iteration 114, loss = 0.00695345
# Validation score: 0.870913
# Iteration 115, loss = 0.00711378
# Validation score: 0.862188
# Iteration 116, loss = 0.00792129
# Validation score: 0.834717
# Iteration 117, loss = 0.00658714
# Validation score: 0.845212
# Iteration 118, loss = 0.00722930
# Validation score: 0.868263
# Iteration 119, loss = 0.00628690
# Validation score: 0.873680
# Iteration 120, loss = 0.00689408
# Validation score: 0.861022
# Iteration 121, loss = 0.00749797
# Validation score: 0.803099
# Iteration 122, loss = 0.00668542
# Validation score: 0.877819
# Iteration 123, loss = 0.00681857
# Validation score: 0.809986
# Iteration 124, loss = 0.00935307
# Validation score: 0.744143
# Iteration 125, loss = 0.00842741
# Validation score: 0.815294
# Iteration 126, loss = 0.00714043
# Validation score: 0.865654
# Iteration 127, loss = 0.00641726
# Validation score: 0.824168
# Iteration 128, loss = 0.00697592
# Validation score: 0.845240
# Iteration 129, loss = 0.00691395
# Validation score: 0.874893
# Iteration 130, loss = 0.00655298
# Validation score: 0.866889
# Iteration 131, loss = 0.00670009
# Validation score: 0.823019
# Iteration 132, loss = 0.00685827
# Validation score: 0.869457
# Iteration 133, loss = 0.00652417
# Validation score: 0.842345
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPRegressor(activation='logistic', early_stopping=True, hidden_layer_sizes=234,
#              learning_rate='adaptive', max_iter=400, validation_fraction=0.2,
#              verbose=True)

# %% [markdown]
# ## 4 Mostrar y guardar los resultados

# %% [markdown]
# Cuando el entrenamiento ha terminado los parámetros (b,w) - bias, weight - de la red se han ajustado de manera que ajustan la salida de la red al conjunto de datos *ytrain*. Estos valores se pueden llamar mediante los atributos *intercepts_* y *coefs_*

# %%
# Mostrar por pantalla los parámetros b y w de la red nuronal
print(net.intercepts_,net.coefs_)
# Out:
# [array([ 0.01873129,  0.00728117,  0.02373231,  0.0386885 ,  0.03691649,
#         0.01890408, -0.03750818, -0.01660081, -0.02839221, -0.0217114 ,
#        -0.028729  ,  0.02008476,  0.01693747, -0.02495662,  0.00493016,
#        -0.03001838,  0.0185207 ,  0.02753354,  0.02013435, -0.02817281,
#        -0.04060094, -0.02867508, -0.00872   ,  0.02202162,  0.00837119,
#        -0.03035145, -0.01556917, -0.02944696,  0.00645464, -0.01441889,
#         0.01080228,  0.01082403,  0.04180024,  0.04048051,  0.04142087,
#         0.01282738, -0.00432427, -0.02679514, -0.01269402, -0.01564631,
#        -0.0167387 ,  0.00539111, -0.03413869,  0.00042254,  0.02655784,
#        -0.00730786,  0.02481378, -0.01325643, -0.00954407,  0.03550374,
#        -0.00680447,  0.0046549 ,  0.03621699, -0.00138837, -0.02242948,
#         0.04236733,  0.03026427, -0.01581053,  0.01950642,  0.00829062,
#        -0.04002977,  0.02781682,  0.03694621, -0.02949814, -0.01792821,
#        -0.03101406,  0.04128151,  0.01920228,  0.00895928,  0.00235117,
#        -0.01765574, -0.02721175,  0.014962  ,  0.01825925,  0.00768608,
#         0.03207679,  0.04584336, -0.0221213 , -0.0077056 ,  0.04154766,
#        -0.0062873 ,  0.00530897,  0.0052554 ,  0.04098505,  0.01013815,
#        -0.01494619,  0.00871543,  0.02019613, -0.03084196, -0.00524577,
#         0.0307427 , -0.03522419, -0.03207137,  0.03487966,  0.01357326,
#         0.02230204, -0.00063841, -0.01039322, -0.00202976,  0.02945727,
#         0.02282733,  0.01080264, -0.01336808,  0.04763916,  0.01279654,
#         0.00647779, -0.01382743, -0.02042549,  0.02199372,  0.01347286,
#        -0.00859401, -0.01286173,  0.03046908, -0.02709884,  0.02838396,
#        -0.01323738,  0.00097732,  0.01774615,  0.01352573, -0.03371069,
#         0.00200881, -0.0231271 ,  0.00766655, -0.01737549, -0.03180554,
#         0.00587532, -0.01427199, -0.04322966, -0.00998933, -0.01717882,
#        -0.00985096, -0.02996896, -0.04690001,  0.04031197, -0.03234824,
#         0.00473201, -0.03885712,  0.00838667, -0.01887535, -0.02773339,
#        -0.01736438,  0.01551937,  0.0070728 , -0.01177461, -0.0449504 ,
#         0.04541174,  0.00930565, -0.01894429, -0.02193716,  0.0173162 ,
#         0.02473202, -0.03778442,  0.02151646, -0.02871985, -0.02926686,
#         0.01228088, -0.00917373, -0.02851354, -0.02402267, -0.00022246,
#         0.00478813, -0.00583314, -0.03447452,  0.0102396 ,  0.04367616,
#        -0.0124498 ,  0.01674503,  0.0100843 , -0.01724168, -0.04777543,
#         0.00348791,  0.03150187,  0.00792177, -0.02240907,  0.02364773,
#         0.00294785, -0.03492732,  0.01779161, -0.01342871, -0.02047166,
#         0.03125828, -0.04005936, -0.0370348 , -0.00525738,  0.00391997,
#        -0.04684833,  0.03328888, -0.0136214 , -0.03244202,  0.02185305,
#        -0.00403437, -0.02518646,  0.01024662, -0.00914787, -0.01075288,
#         0.02696233, -0.00902251,  0.01538048,  0.01227501, -0.03126402,
#        -0.03531553,  0.0167007 , -0.02865741,  0.00015974,  0.00924665,
#        -0.02534895,  0.03001697, -0.03924732,  0.04258417,  0.03847892,
#        -0.03348019, -0.00208159,  0.01208266, -0.02829816, -0.01445078,
#        -0.01088145, -0.00024759,  0.00313342,  0.00587782,  0.0264082 ,
#        -0.03471694,  0.00049471, -0.0264864 ,  0.00805046,  0.03232182,
#         0.02208182,  0.02132726, -0.0227498 , -0.02421304, -0.03068119,
#        -0.01159037, -0.0099124 ,  0.00443683, -0.0205254 ]), array([-0.07808928,  0.05786542,  0.01301704])] [array([[-0.02291704, -0.03589623, -0.03577215, ...,  0.04931847,
#         -0.04516824,  0.01517287],
#        [-0.01047189,  0.01379609, -0.00775722, ..., -0.00748271,
#          0.01586281, -0.0220341 ],
#        [ 0.04583554,  0.00496973,  0.00573549, ...,  0.02087478,
#         -0.01886778, -0.01825018],
#        ...,
#        [-0.01993454, -0.02190319,  0.00039896, ..., -0.04191072,
#          0.00176459,  0.01336951],
#        [ 0.02283552,  0.02273242, -0.02367828, ..., -0.00558137,
#          0.0099736 , -0.02389215],
#        [-0.01547391,  0.00458146,  0.00322571, ...,  0.01280154,
#         -0.02385756,  0.00327546]]), array([[ 0.04083888,  0.03333566,  0.02990415],
#        [ 0.032867  ,  0.09562177, -0.05766962],
#        [-0.04181214,  0.06978938, -0.0631406 ],
#        [-0.02745542,  0.11823883,  0.07748513],
#        [-0.09448168,  0.08480785,  0.04644236],
#        [-0.00231704,  0.00454194,  0.00276403],
#        [-0.0084018 , -0.07697927, -0.00105261],
#        [-0.08060455,  0.05173764, -0.02979654],
#        [ 0.02866104, -0.01228673,  0.08963202],
#        [ 0.02583352,  0.13360789,  0.05742933],
#        [-0.01780894, -0.06980003, -0.07767753],
#        [-0.08402784,  0.0431395 , -0.09836611],
#        [-0.01028806, -0.06222445,  0.10583504],
#        [-0.06512272, -0.00699744,  0.0676393 ],
#        [ 0.06507094, -0.00511102, -0.01168833],
#        [-0.10158713,  0.02153271,  0.02004429],
#        [ 0.03755881, -0.04653327,  0.05939159],
#        [ 0.07982706, -0.02658883, -0.07514237],
#        [ 0.07925332, -0.06733584, -0.03889538],
#        [-0.02060007,  0.14502515,  0.06535792],
#        [-0.02579758,  0.00063534,  0.01817929],
#        [-0.08052166,  0.03295292,  0.10854192],
#        [ 0.05285637,  0.08294849, -0.08446443],
#        [ 0.05773439,  0.0461571 ,  0.0289059 ],
#        [ 0.06268159,  0.08086055, -0.07823357],
#        [-0.08173262,  0.07345201,  0.05527746],
#        [-0.08655257,  0.02241102, -0.02297323],
#        [-0.07765136,  0.05624484, -0.00488989],
#        [-0.01766501,  0.02457242,  0.10643581],
#        [ 0.03247216, -0.09118998,  0.00849639],
#        [ 0.05937107,  0.06361564,  0.06669281],
#        [ 0.08102944, -0.07368766,  0.07640852],
#        [ 0.07326778,  0.03768329,  0.03261284],
#        [ 0.002756  ,  0.03852902,  0.07659616],
#        [ 0.09060172, -0.00936815, -0.02761896],
#        [ 0.07156234,  0.07956741, -0.01123958],
#        [-0.01739037, -0.00971024, -0.05196925],
#        [-0.00785934,  0.10428511,  0.11562947],
#        [ 0.06606243,  0.03150349, -0.06421551],
#        [-0.04104426, -0.15067535, -0.04219337],
#        [ 0.01021336, -0.08826948, -0.0638637 ],
#        [ 0.03395867, -0.02040241, -0.03969398],
#        [ 0.08564616,  0.08019304, -0.07676175],
#        [-0.03599743,  0.06119791,  0.04740515],
#        [ 0.07774065,  0.03266165, -0.06946267],
#        [-0.04062666,  0.06267388, -0.01199969],
#        [-0.06371129, -0.01790668, -0.06043723],
#        [ 0.0573432 ,  0.08873036, -0.02383918],
#        [-0.02054421, -0.08654069, -0.11568018],
#        [ 0.04150841, -0.0349849 , -0.03455803],
#        [-0.04954408,  0.05588257,  0.08367824],
#        [-0.09621208,  0.07896027, -0.0910976 ],
#        [ 0.07049761,  0.08255728,  0.10459402],
#        [-0.06321837, -0.0405228 ,  0.08247496],
#        [-0.04154421, -0.03222972,  0.07552636],
#        [ 0.03372095, -0.04314982,  0.0549688 ],
#        [ 0.01920693,  0.08250407,  0.02176681],
#        [-0.07447733,  0.08478803,  0.00645775],
#        [-0.06586726, -0.08555682, -0.09025245],
#        [-0.01078454,  0.06694761, -0.07801565],
#        [-0.10605099,  0.00098787,  0.03972776],
#        [-0.0816726 ,  0.03950114,  0.01391529],
#        [-0.0738274 ,  0.0536801 ,  0.07344007],
#        [-0.0311986 , -0.06450579, -0.10945203],
#        [-0.00058452, -0.04980382, -0.02934629],
#        [ 0.07743782,  0.0119763 , -0.02735569],
#        [ 0.01689591, -0.12070516,  0.01334896],
#        [ 0.07428818,  0.03306664, -0.07548153],
#        [ 0.03789972,  0.14089036,  0.0635674 ],
#        [ 0.05949658,  0.01117078,  0.02738317],
#        [-0.06149274, -0.03444551,  0.05800064],
#        [-0.057569  , -0.0403989 ,  0.01546168],
#        [-0.07762387,  0.02887461, -0.06382731],
#        [ 0.08434761, -0.01036234, -0.03195179],
#        [-0.04724275,  0.05610369, -0.03788275],
#        [-0.08514838,  0.04533558, -0.05767935],
#        [ 0.01315292, -0.08357723,  0.03736228],
#        [-0.07470672, -0.05331909,  0.07844142],
#        [ 0.05598944,  0.07591879, -0.04790478],
#        [ 0.04164679,  0.09485322,  0.03391206],
#        [ 0.05929651, -0.10654588,  0.00922499],
#        [ 0.01227267,  0.06560176, -0.03114938],
#        [-0.08902924, -0.00500499,  0.03193081],
#        [ 0.00052681, -0.12203078, -0.00557987],
#        [-0.01381191,  0.04165072,  0.05315266],
#        [ 0.0864729 ,  0.10876977, -0.07150966],
#        [-0.09322609,  0.05456558, -0.05424035],
#        [-0.06467404, -0.04174311, -0.08542246],
#        [-0.07669772, -0.04589539,  0.07040295],
#        [-0.0403983 ,  0.03584321, -0.08724115],
#        [ 0.04286828,  0.05515231,  0.08194083],
#        [-0.00902186, -0.02499259, -0.07279276],
#        [-0.02896211, -0.03466198, -0.0004215 ],
#        [-0.0733994 ,  0.04072315,  0.09108436],
#        [-0.05475651, -0.06321338,  0.01116677],
#        [-0.06240923,  0.04705963, -0.01066008],
#        [ 0.04494558,  0.02695204,  0.0218451 ],
#        [-0.06039074, -0.07870163,  0.07063636],
#        [-0.00768019, -0.03454205,  0.02730404],
#        [-0.02736377,  0.08610353,  0.02577853],
#        [ 0.01077191, -0.03678421, -0.03034924],
#        [-0.05466198,  0.06614955,  0.07400577],
#        [ 0.05040581, -0.00837432, -0.02662821],
#        [ 0.00960484, -0.0293112 ,  0.06389592],
#        [ 0.04997975,  0.0464945 ,  0.09868068],
#        [ 0.04858321,  0.02323477,  0.08480306],
#        [-0.03463895, -0.02676693, -0.04326807],
#        [-0.0899228 , -0.00724961, -0.0808146 ],
#        [ 0.06620786,  0.06172659, -0.02767715],
#        [ 0.03865574, -0.01579094, -0.0658125 ],
#        [ 0.08822183,  0.06432085,  0.08048045],
#        [ 0.08687052, -0.00553956,  0.04679459],
#        [-0.02807654,  0.02477508, -0.04146597],
#        [ 0.06165143, -0.04620681, -0.02065102],
#        [-0.032189  , -0.05111071, -0.00126738],
#        [-0.03164723,  0.10177849,  0.10709783],
#        [ 0.06223332,  0.0822154 ,  0.0358328 ],
#        [-0.10458411, -0.03862048,  0.07449432],
#        [-0.07844708,  0.0470913 ,  0.02399684],
#        [ 0.04459359, -0.02696033, -0.00190418],
#        [-0.0260629 , -0.12361825,  0.05718597],
#        [ 0.04068217,  0.08416541,  0.05463911],
#        [ 0.01675662, -0.03196364,  0.02344114],
#        [ 0.0647699 ,  0.06052493, -0.04672852],
#        [ 0.02903153, -0.07025501, -0.03703101],
#        [ 0.08072783, -0.01248724,  0.05969857],
#        [ 0.05715351,  0.09230342,  0.04060264],
#        [-0.07191459, -0.05131408, -0.05183702],
#        [ 0.01320066, -0.02544412,  0.09457068],
#        [-0.08058708, -0.06738676, -0.05013046],
#        [-0.04496825,  0.10798412, -0.00364022],
#        [ 0.04756531,  0.01030112,  0.05898391],
#        [-0.04404405,  0.01832143, -0.03437233],
#        [-0.04275738,  0.05383122,  0.11942733],
#        [ 0.02050647, -0.11146202, -0.0401529 ],
#        [ 0.09295348, -0.0653891 ,  0.01866991],
#        [-0.06757925,  0.09691448, -0.08575031],
#        [-0.08566833,  0.08040021, -0.0548057 ],
#        [ 0.0104298 , -0.07697645,  0.05445699],
#        [-0.06117261,  0.02864342,  0.06372745],
#        [ 0.04709561, -0.03531352,  0.04718789],
#        [-0.0761377 , -0.0318818 ,  0.03893685],
#        [ 0.0056105 ,  0.00331047, -0.03782166],
#        [-0.02260716, -0.10205649, -0.04862472],
#        [ 0.02150045, -0.08651732, -0.11761982],
#        [-0.03870043,  0.12665528,  0.11443582],
#        [-0.02312777,  0.02124346,  0.08567019],
#        [ 0.07610242, -0.0682834 ,  0.06272598],
#        [ 0.06845341,  0.04838538, -0.06619826],
#        [ 0.07327318, -0.02203019, -0.07952924],
#        [-0.05218245, -0.00497053, -0.05726501],
#        [ 0.01298606, -0.08563964, -0.07201196],
#        [ 0.00948518, -0.02806692,  0.08337295],
#        [-0.07272318,  0.07594866,  0.08960918],
#        [ 0.04060979,  0.06820245, -0.01488653],
#        [-0.01099571, -0.04871593, -0.12641502],
#        [-0.0216978 , -0.07538511,  0.01994839],
#        [-0.06551505,  0.10561677, -0.00897292],
#        [ 0.04447572, -0.05846429, -0.08083018],
#        [ 0.05449712,  0.08964616,  0.06095704],
#        [ 0.06791713,  0.10416157,  0.03999008],
#        [-0.03840047,  0.04912482,  0.09966375],
#        [ 0.08657563,  0.03288013,  0.02923939],
#        [-0.00973333, -0.11857068, -0.06171775],
#        [ 0.07295144, -0.00550823,  0.04351996],
#        [-0.09091828,  0.06065692, -0.07470277],
#        [-0.0282015 ,  0.10926389, -0.0781463 ],
#        [ 0.00706145,  0.11201379,  0.09677972],
#        [-0.017136  , -0.05763716, -0.06490391],
#        [ 0.01044776, -0.03604342, -0.02063324],
#        [-0.09963736,  0.06529789, -0.03959978],
#        [-0.03079912, -0.05275882, -0.00827998],
#        [ 0.06769727,  0.00017542,  0.06786925],
#        [ 0.00760158, -0.10767901,  0.10836068],
#        [ 0.00640942,  0.01363227,  0.05023014],
#        [ 0.05291699,  0.08652808,  0.00076916],
#        [-0.0235495 , -0.05424137, -0.09931176],
#        [-0.07028027, -0.10816485, -0.05546993],
#        [ 0.00849941,  0.08417726,  0.0625978 ],
#        [-0.06818308, -0.1131758 ,  0.02322402],
#        [ 0.09606466, -0.05276887,  0.08340828],
#        [-0.0436284 ,  0.09517293,  0.02631214],
#        [-0.04098814, -0.02747897,  0.0339291 ],
#        [-0.0401339 , -0.06049434, -0.10549069],
#        [ 0.02036267,  0.10153865, -0.05170957],
#        [-0.06682589, -0.03304402, -0.07345909],
#        [-0.08230947, -0.05514683, -0.01794897],
#        [ 0.03205509,  0.04883323,  0.12708302],
#        [-0.03858623,  0.02523155,  0.08861254],
#        [ 0.06759234,  0.07010551,  0.03173221],
#        [ 0.04173255, -0.09286021, -0.10641254],
#        [ 0.02997097, -0.00368695,  0.09002005],
#        [-0.0835864 ,  0.01191845,  0.04961452],
#        [-0.00583069,  0.14427683,  0.08409052],
#        [-0.00626249,  0.06328768, -0.04438612],
#        [ 0.05506992, -0.0321727 ,  0.06450912],
#        [ 0.03077935,  0.14489803,  0.05276462],
#        [-0.01949697,  0.14170939,  0.07643424],
#        [ 0.03422818,  0.01706647, -0.02043074],
#        [-0.05944255,  0.07807175, -0.03284959],
#        [-0.01005727,  0.02563882, -0.07661657],
#        [ 0.05844347,  0.06647669,  0.04682071],
#        [ 0.06532424, -0.08408254,  0.07294782],
#        [-0.0540507 ,  0.04418936,  0.02462926],
#        [ 0.01611463, -0.09319614, -0.0980941 ],
#        [ 0.08698416,  0.06444894, -0.02290747],
#        [-0.06746267, -0.06441898, -0.04281376],
#        [-0.07859685,  0.07047288, -0.09576977],
#        [ 0.01191028, -0.15275454,  0.08385915],
#        [ 0.0015359 ,  0.06925365,  0.04241173],
#        [ 0.08535576,  0.02195317,  0.05898083],
#        [-0.07271652, -0.07691729, -0.10224291],
#        [-0.05857065, -0.07740376, -0.06885061],
#        [-0.06844918,  0.01171746, -0.03937397],
#        [-0.01417662, -0.02843206, -0.04166398],
#        [-0.01511255,  0.1214992 , -0.09747544],
#        [-0.09763397, -0.08722635, -0.03370014],
#        [-0.07052082,  0.09593788,  0.04259988],
#        [ 0.0576595 , -0.04014481, -0.04577356],
#        [ 0.07182169, -0.00486556,  0.00235358],
#        [-0.04442705, -0.07465163, -0.02591472],
#        [-0.08294587, -0.01489321,  0.08978193],
#        [-0.0095065 , -0.07134888, -0.05917037],
#        [ 0.08510081, -0.0591102 , -0.09913973],
#        [ 0.02848829, -0.03299461, -0.02041513],
#        [ 0.06935393,  0.01754668, -0.06520833],
#        [ 0.03640388,  0.0209718 , -0.11663507],
#        [-0.08233331, -0.03647138,  0.01647754],
#        [ 0.04942482, -0.07761092,  0.05294915],
#        [ 0.05298663, -0.08318233,  0.06593441],
#        [-0.08458652,  0.03940699, -0.0726432 ],
#        [-0.03040919,  0.0665591 ,  0.02063209],
#        [-0.01499299,  0.01283209, -0.08592535],
#        [-0.01785692,  0.04789604,  0.04141238]])]

# %% [markdown]
# Para guardar la red neuronal ya entrenada vamos a utilizar la librería *pickle* de Python. Los comandos a ejecutar son:
# ```
# output_file_name = "nombre de salida del fichero a guardar"
# pickle.dump(nombre_de_la_red,open(output_file_name,"wb"))
# ```

# %%
# Rellenar la celda con el código necesario para guardar la red
output_file_name = "out_net.pkl"
pickle.dump(net,open(output_file_name,"wb"))

# %% [markdown]
# El valor de pérdida (el error cuadrático entre la salida de la red y los valores ytrain) de la red se puede obtener llamando al atributo *loss_* mientras que los valores para cada iteración se obtienen con el atributo *loss_curve_*

# %%
# Muestra por pantalla el valor actual de pérdida y dibuja en una gráfica la curva de pérdida
net.loss_
# Out:
# 0.00652416605336099

# %%
# Mustra por pantalla el score para el conjunto de entrenamiento. 
#¿Cómo compara con el valor mostrado en el entrenamiento con el del conjunto de validación?
net.score(xtrain,ytrain)
# Out:
# 0.8747515992076869

# %% [markdown]
# ## 5 Estudio de las incertidumbres

# %% [markdown]
# Una vez entrenada la red se utiliza el conjunto *test* para comprobar los resultados y caracterizar las incertidumbres. Dado un conjunto de espectros de entrada, la red asignará a cada espectro un valor de salida que corresponde con una temperatura, una gravedad y una metalicidad. Para obtener estos valores se utiliza el método *predict()* de la red neuronal.
#
# Hay que recordar que la red fue entrenada con los objetivos (valores de salida) escalados y hay que desescalarlos.

# %%
# Obtener los parámetros estelares que la red entrenada asocia a los espectros del conjunto test
# Recordar que los valores de los parámetros con los que se entrenó la red han sido escalados.

test_predictions = scaler.inverse_transform(net.____(_____)) # rellenar los huecos con los valores para obtener las predicciones de la red asociadas a los espectros del conjunto test
test_values = # rellenar para obtener los valores de los parámetros reales del conjunto test

print(___) # rellenar para mostrar los valores de las predicciones

# %% [markdown]
# El error medio o *bias* para cada variable viene dado por el valor medio de la distribución *valores_de_la_red* - *valores_reales*. Para obtener estas distribuciones tenemos que acceder a los elementos de *test_predictions* y *test_values* que corresponden a cada parámetro astrofísico. Éstos están guardados en el orden en que los definimos (temperatura, gravedad, metalicidad).
#
# Dado un *array* de *arrays*, si se quiere acceder al primer elemento de cada uno de los *arrays* se puede utilizar la siguiente nomenclatura:
# ```
# primer_valor_cada_array = array_de_array[:,0]
# ```
# Cambiando el índice se puede obtener todos los segundos, los terceros, etc.

# %%
# Construir las distribuciones de predicciones menos valores reales
delta_teff = test_predictions[____] - test_values[___] # rellenar los huecos
delta_logg = ___ # rellenar
delta_mh = _____ # rellenar

# %%
# Ilustrar en un gráfico las distribuciones de diferencias (deltas). Para ello pintar un histograma usando plt.hist().

# %%
# en esta celda vamos a obtener los biases y las uncertidumbres.
# para obtenerlas hay que utilizar los métodos mean() y std() 
bias_teff = _____
bias_logg = _____
bias_mh = _____
uncert_teff = ____
uncert_logg = ____
uncert_mh = ____

# %%
# mostrar los resultados de bias y uncert para cada variable

# %% [markdown]
# ## 6 Nota final para el entrenamiento

# %% [markdown]
# Normalmente hay que realizar un estudio detallado para encontrar la configuración óptima de la red a través de los posibles valores de parámetros e hiperparámetros. La configuración óptima dependerá del tipo de problema que se quiere resolver, los datos de entrenamiento...; por ello es bueno cambiar la arquitectura y los valores de los parámetros y entrenar con los mismos datos.
#
# Utiliza las celdas de debajo (tantas como necesites) para construir nuevas redes y comparar los resultados que dan cada una de ellas

# %% [markdown]
# ## 7 Aplicación a espectros reales (medidos por RAVE)

# %% [markdown]
# Ahora se va a aplicar la red neuronal entrenada a datos reales.
# Los ficheros *input_spectra_X.pkl* contienen espectros medidos por el experimento [RAVE](https://www.rave-survey.org/) y, a partir de ellos, la red neuronal va a asignar a cada espectro una temperatura efectiva, un logaritmo de la gravedad y una metalicidad. Posteriormente, se mostrará en un gráfico las gravedades frente a las temperaturas. Así, el esquema de este análisis es:
# - Lectura de datos: entender las diferencias entre los datos y las simulaciones
# - Determinación de los parámetros astrofísicos
# - Dibujar el diagrama de logg vs Teff (¿es, en tu caso, necesaria una corrección?)

# %% [markdown]
# ### 7.1 Lectura de datos
#
# Puesto que los ficheros de datos están separados, por comodidad vamos a crear un *DataFrame* vacío y, mediante un bucle for, vamos a ir almacenando las tablas de cada fichero en el mismo *DataFrame*.

# %%
# rellenar el hueco para leer los datos y almacenarlos en data
data = pd.DataFrame()
for i in range(20):
    data = pd.concat((_____,pd._____("data/input_spectra_{}.pkl".format(i))))

# %%
# pintar algunos espectros
idx = ___ 
plt.figure(figsize=(13,8))
plt.plot(____,____)
plt.xlabel(r"$\lambda /nm$")
plt.ylabel(r"$Normalized flux$")

# %% [markdown]
# ### 7.2 Inferencia: determinación de parámetros astrofísicos

# %%
data_specs = _____.______.tolist() # obtener los valores de los espectros. Nota: se convierte a una lista porque MLPRegressor.predict recibe como argumento una lista
data_preds = _____ # aplicar la red neuronal

# %%
# Utiliza esta celda (y tantas como necesites) para explorar los resultados

# %% [markdown]
# ### 7.3 Diagrama de inferencias

# %%
# rellenar para dibujar el diagrama.
# Nota: el diagrama que se quiere dibujar debe tener los ejes invertidos. Si se quiere dibujar el eje X invertido hay que llamar a la instrucción plt.gca().invert_xaxis()
